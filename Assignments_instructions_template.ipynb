# %% [markdown]
# #### **Drew Bresingham**, ambresin@ncsu.edu, and _200339447_. ####
# #### **NR491 Fall 2022** *Storymap* ####
# Insert your NAME, email, and student ID, course name and howmework number.
#
# Save this notebook somewhere on your google drive and email the link to that homework to
# Mollie and Mirela.
# If we need to use your data to test if the hw works (likely unless we've given you the data), please share the link to the entire homework folder (e.g.,Landsat_HW2) and have a "data" subfolder that you point to in the code. Make sure we have editing rights to that folder otherwise we won't be able to run it.
# DO NOT include hard coded paths in your homework submission. We will not be able to run it and
# assess your homework. If you are using a different environment to the one we are using, make sure
# you save that in the folder and load the environment. Tell us what package you needed to add to run your homework (i.e. the reason you had to modify your environment).
# Copy paste your Jupyter notebook text to a word doc or google docx for spelling and grammer errors and once corrected copy it back here.

# %% [markdown]
# [Jupyter](https://jupyter.org/) notebooks are a way to share executable code and Markdown text describing objectives, answering question, etc. You can include pictures, links, mathematical equations, and videos.

# %% [markdown]
# To execute the code in a particular cell, click on the cell and hit shift-enter or click the 'Run cell' button (play button w/ downward pointing arrow). To go in Markdown mode for a cell choose "Change to markdown" (from the 3 dots ... menu). It's typically good to run all code once before executing a cell to do all the imports and initialize variables.

# %%
print("Hi, this is my HW")
# Out:
# Hi, this is my HW

# %% [markdown]
# #### To format text
# Double click on this cell to reveal the unformatted text.
#
# As you can see below, formatting text characters apply to markdown cells
#
# To insert italics, use *asterisks* or _underscores_.
#
# To bold text, use **asterisks** or __underscores__.
#
# Combined emphasis with **_asterisks and underscores_**.
#
# Strikethrough uses ~~two tildes~~.
#
# To include a link: [This is my website](http://www.mirela-tulbure.com/)
#
# If you want to use a formula: $e = mc^2$

# %%
#### If you want to insert an image from the web:
from IPython.display import Image
Image(url='http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif"/>

# %%
import pandas as pd
import geopandas as gpd
import os
import folium
import csv
from pathlib import Path
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import Normalize
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np

# %%
header = ['Setting', 'Customize', 'Hints']
info = ['Storymap Info', '', \
    'For help, see tutorial in [HandsOnDataViz.org](https://handsondataviz.org/leaflet-storymaps-with-google-sheets.html)']
title = ['Storymap Title', 'Schooling and Poverty', '']
subtitle = ['Storymap Subtitle', \
    "Public and Private Schools with county poverty spread in Illinois and North Carolina<br><small>Scroll down<i class='fafa-chevron-down'></i></small>",\
    "Add your subtitle, or delete that portion"]
logo = ['Storymap Logo', 'media/ncsu_logo.jpg', 'Path to a logo image']
google_analysis = ['Google Analytics Tracking ID', '', 'Sample format: UA-5488840-29']

map_settings = ['Map Settings', '', '']
basemap_tiles = ['Basemap Tiles', 'CartoDB.Positron',\
    '[Drop-down menu for background basemap tiles](https://leaflet-extras.github.io/leaflet-providers/preview/)']
zoom = ['Zoom Controls', 'bottomright', '']
bg_color = ['Narrative Background Color', '', '']
txt_color = ['Narrative Text Color', '', '']
lnk_color = ['Narrative Link Color', '', '']
ch_color = ['Active Chapter Background Color','','']
media_height = ['Media Container Height','300',\
    'Maximum height of the image, in pixels. 200 is default. The image will be fit into the container with its proportions kept (it won\'t be skewed).']
pixels_after_char = ['Pixels After Final Chapter','600','In pixels, at least 100']
lightbox_imgs = ['Enable Lightbox for Images','yes','yes or no']

creds = ['Credits','','']
auth_name = ['Author Name','Drew Bresingham','Appears in map credits as "View data by..." (or leave blank)']
auth_email = ['Author Email or Website','','Create link in Author Name by inserting your email or web address (or leave blank)']
auth_GH = ['Author GitHub Repo Link','https://github.com/handsondataviz/leaflet-storymaps-with-google-sheets',\
    'Insert your code repo URL to appear as link in "View code..." (or leave blank)']
code_cred = ['Code Credit','<a href="https://handsondataviz.org">HandsOnDataViz</a>',\
    'Appears in credits as "...code by..." (or leave blank)']

# %%
if not os.path.exists('./csv'):
    os.mkdir('./csv')

with open('./csv/Options_Template.csv', 'w', newline='') as options:
    # create the csv writer
    writer = csv.writer(options)

    # write a row to the csv file
    writer.writerow(header)

    writer.writerow(info)
    writer.writerow(title)
    writer.writerow(subtitle)
    writer.writerow(logo)
    writer.writerow(google_analysis)

    writer.writerow(map_settings)
    writer.writerow(basemap_tiles)
    writer.writerow(zoom)
    writer.writerow(bg_color)
    writer.writerow(txt_color)
    writer.writerow(lnk_color)
    writer.writerow(ch_color)
    writer.writerow(media_height)
    writer.writerow(pixels_after_char)
    writer.writerow(lightbox_imgs)
    writer.writerow(creds)
    writer.writerow(auth_name)
    writer.writerow(auth_email)
    writer.writerow(auth_GH)
    writer.writerow(code_cred)

# %%
options_df = pd.read_csv('./csv/Options_Template.csv', index_col=0)
options_df
# Out:
#                                                                          Customize  \
# Setting
# Storymap Info                                                                  NaN
# Storymap Title                                               Schooling and Poverty
# Storymap Subtitle                Public and Private Schools with county poverty...
# Storymap Logo                                                  media/ncsu_logo.jpg
# Google Analytics Tracking ID                                                   NaN
# Map Settings                                                                   NaN
# Basemap Tiles                                                     CartoDB.Positron
# Zoom Controls                                                          bottomright
# Narrative Background Color                                                     NaN
# Narrative Text Color                                                           NaN
# ...

# %%
options_df['Customize']['Narrative Background Color'] = 'lightgray'

options_df
# Out:
#                                                                          Customize  \
# Setting
# Storymap Info                                                                  NaN
# Storymap Title                                               Schooling and Poverty
# Storymap Subtitle                Public and Private Schools with county poverty...
# Storymap Logo                                                  media/ncsu_logo.jpg
# Google Analytics Tracking ID                                                   NaN
# Map Settings                                                                   NaN
# Basemap Tiles                                                     CartoDB.Positron
# Zoom Controls                                                          bottomright
# Narrative Background Color                                               lightgray
# Narrative Text Color                                                           NaN
# ...

# %%
options_df['Customize']['Author Name'] = 'Drew Bresingham'
options_df['Customize']['Author Github Repo Link'] = 'https://github.com/Bresh10/NR-491-Final'
options_df.to_csv('./csv/Options.csv')

# %%
shp = gpd.read_file('./data/tl_2021_us_county/tl_2021_us_county.shp')

# %%
NCcounties = shp[(shp['STATEFP'] == '37')]

NCcounties
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID          NAME             NAMELSAD  \
# 23        37      037  01008544  37037       Chatham       Chatham County
# 59        37      001  01008531  37001      Alamance      Alamance County
# 91        37      057  01008548  37057      Davidson      Davidson County
# 182       37      069  01008553  37069      Franklin      Franklin County
# 219       37      155  01026130  37155       Robeson       Robeson County
# ...      ...      ...       ...    ...           ...                  ...
# 3112      37      175  01008589  37175  Transylvania  Transylvania County
# 3113      37      171  01008587  37171         Surry         Surry County
# 3155      37      043  01008546  37043          Clay          Clay County
# 3164      37      055  01026133  37055          Dare          Dare County
# 3170      37      047  01026339  37047      Columbus      Columbus County
#
#      LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND  \
# ...

# %%
shp2 = gpd.read_file('./data/School Districts/schooldistrict_sy2021_tl21.shp')

# %%
NCDistricts = shp2[(shp2['STATEFP'] == '37')]

NCDistricts
# Out:
#       STATEFP ELSDLEA SCSDLEA UNSDLEA    GEOID                          NAME  \
# 11011      37    None    None   00011  3700011     Cumberland County Schools
# 11012      37    None    None   00012  3700012           Pitt County Schools
# 11013      37    None    None   00013  3700013          Camp Lejeune Schools
# 11014      37    None    None   00014  3700014            Fort Bragg Schools
# 11015      37    None    None   00030  3700030   Alamance-Burlington Schools
# ...       ...     ...     ...     ...      ...                           ...
# 11124      37    None    None   04950  3704950         Wilkes County Schools
# 11125      37    None    None   05020  3705020         Wilson County Schools
# 11126      37    None    None   05040  3705040         Yadkin County Schools
# 11127      37    None    None   05070  3705070         Yancey County Schools
# 11128      37    None    None   37099  3737099  Eastern Cherokee Reservation
#
# ...

# %%
shp3 = gpd.read_file('./data/NC Public Schools/Public_Schools.shp')

# %%
NCPublic = shp3[(shp3['sch_desg'] == 'Public')]

# %%
NCPublic = shp3[(shp3['sch_ctype'] == 'Traditional')]

# %%
NCPublic = shp3[(shp3['sch_ptype'] == 'None')]

# %%
shp4 = gpd.read_file('./data/NC Private Schools/Non-Public_Schools.shp')

# %%
NCPrivate = shp4[(shp4['schooltype'] == 'Independent')]

# %%
print('NC counties CRS: {0}'.format(NCcounties.crs))
print('NC Districts CRS: {0}'.format(NCDistricts.crs))
print('NC Public School CRS: {0}'.format(NCPublic.crs))
print('NC Private School CRS: {0}'.format(NCPrivate.crs))
# Out:
# NC counties CRS: epsg:4269
# NC Districts CRS: epsg:4269
# NC Public School CRS: epsg:4326
# NC Private School CRS: epsg:32119

# %%
NCcounties_epsg = NCcounties.crs.to_epsg()
print(NCcounties_epsg)
NCPublic42 = NCPublic.to_crs(NCcounties_epsg)
NCPublic42.crs
# Out:
# 4269
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
NCPublic42.head()
# Out:
#    objectid lea_school    ptmoved         comments reviewed  \
# 1         2      70340  yes, 2012  down the street        1
# 2         3      70326       None             None     None
# 3         4      70308       None   point verified        1
# 4         5     740309       None             None     None
# 5         6     740308       None             None     None
#
#                school_nam        principal         street_lon  \
# 1  S W Snowden Elementary     Melissa Dana  6921 NC 306 North
# 2     Chocowinity Primary  Alicia Vosburgh      606 Gray Road
# 3         Bath Elementary    Pamela Hodges  110 S King Street
# 4       AydenGrifton High      Marty Baker   7653 NC 11 South
# 5            Ayden Middle       Jeff Theus       192 Third St
#
#               phys_addr    phys_city  ...  ext_hours  num_teach bgn_grade  \
# 1  693 North 7th Street       Aurora  ...          -         15        PK
# 2         606 Gray Road  Chocowinity  ...          -         33        PK
# ...

# %%
NCPrivate42 = NCPrivate.to_crs(NCcounties_epsg)
NCPrivate42.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
NCPrivate42.head()
# Out:
#     objectid_1  objectid  schoolid     county  \
# 5            6         6     59355   Alamance
# 6            7         7     79104   Alamance
# 7            8         8     85553   Alamance
# 12          13        13     85555   Alamance
# 17          18        18    102862  Alexander
#
#                             schoolname                   address  \
# 5                    Burlington School    1615 Greenwood Terrace
# 6   Children's House Montessori School        3750 Alamance Road
# 7                          Elon School  201 South O'Kelly Avenue
# 12         Youth Train Ventures School     915 South Main Street
# 17          Walkers Day Program School            137 7th Street
#
#             city state  zipcode                     website   schooltype  \
# 5     Burlington    NC    27215  ww.theburlingtonschool.org  Independent
# 6     Burlington    NC    27215        www.chmontessori.org  Independent
# ...

# %%
Wake_County = shp[(shp['NAMELSAD'] == 'Wake County')]
Wake_County
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID  NAME     NAMELSAD LSAD CLASSFP  MTFCC  \
# 2372      37      183  01008592  37183  Wake  Wake County   06      H1  G4020
#
#      CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 2372   450  39580     None        A  2161639293  58012743  +35.7898464
#
#           INTPTLON                                           geometry
# 2372  -078.6506240  POLYGON ((-78.69436 35.53008, -78.69456 35.529...

# %%
Wake_District = shp2[(shp2['GEOID'] == '3704720')]
Wake_District
# Out:
#       STATEFP ELSDLEA SCSDLEA UNSDLEA    GEOID                 NAME LSAD  \
# 11117      37    None    None   04720  3704720  Wake County Schools   00
#
#       LOGRADE HIGRADE  MTFCC SDTYP FUNCSTAT         ALAND      AWATER  \
# 11117      PK      12  G5420  None        E  2.161639e+09  58012743.0
#
#           INTPTLAT      INTPTLON GEO_YEAR SCHOOLYEAR  \
# 11117  +35.7898464  -078.6506240     2021  2020-2021
#
#                                                 geometry
# 11117  POLYGON ((-78.54641 36.02183, -78.54097 36.019...

# %%
Wake_Public = NCPublic42[(NCPublic42['county'] == 'Wake')]

# %%
Wake_Private = NCPrivate42[(NCPrivate42['county'] == 'Wake')]

# %%
poverty = pd.read_csv('data/poverty.csv')
poverty.head()
# Out:
#                                    Label (Grouping)  \
# 0  Population for whom poverty status is determined
# 1                                               AGE
# 2                                    Under 18 years
# 3                                     Under 5 years
# 4                                     5 to 17 years
#
#   Alamance County, North Carolina!!Total!!Estimate  \
# 0                                          161,433
# 1                                              NaN
# 2                                           36,185
# 3                                            9,338
# 4                                           26,847
#
#   Alamance County, North Carolina!!Below poverty level!!Estimate  \
# 0                                             24,893
# 1                                                NaN
# 2                                              8,048
# 3                                              2,105
# 4                                              5,943
#
# ...

# %%
col_names = poverty.columns.to_list()
col_names
# Out:
# ['Label (Grouping)',
#  'Alamance County, North Carolina!!Total!!Estimate',
#  'Alamance County, North Carolina!!Below poverty level!!Estimate',
#  'Alamance County, North Carolina!!Percent below poverty level!!Estimate',
#  'Alexander County, North Carolina!!Total!!Estimate',
#  'Alexander County, North Carolina!!Below poverty level!!Estimate',
#  'Alexander County, North Carolina!!Percent below poverty level!!Estimate',
#  'Alleghany County, North Carolina!!Total!!Estimate',
#  'Alleghany County, North Carolina!!Below poverty level!!Estimate',
#  'Alleghany County, North Carolina!!Percent below poverty level!!Estimate',
#  'Anson County, North Carolina!!Total!!Estimate',
#  'Anson County, North Carolina!!Below poverty level!!Estimate',
#  'Anson County, North Carolina!!Percent below poverty level!!Estimate',
#  'Ashe County, North Carolina!!Total!!Estimate',
#  'Ashe County, North Carolina!!Below poverty level!!Estimate',
# ...

# %%
to_rename = {' County, North Carolina!!Total!!Estimate':'_total',
             ' County, North Carolina!!Below poverty level!!Estimate':'_estimate',
             ' County, North Carolina!!Percent below poverty level!!Estimate':'_percentage'}
to_rename
# Out:
# {' County, North Carolina!!Total!!Estimate': '_total',
#  ' County, North Carolina!!Below poverty level!!Estimate': '_estimate',
#  ' County, North Carolina!!Percent below poverty level!!Estimate': '_percentage'}

# %%
for index,col in enumerate(col_names):
    print(index, col)
# Out:
# 0 Label (Grouping)
# 1 Alamance County, North Carolina!!Total!!Estimate
# 2 Alamance County, North Carolina!!Below poverty level!!Estimate
# 3 Alamance County, North Carolina!!Percent below poverty level!!Estimate
# 4 Alexander County, North Carolina!!Total!!Estimate
# 5 Alexander County, North Carolina!!Below poverty level!!Estimate
# 6 Alexander County, North Carolina!!Percent below poverty level!!Estimate
# 7 Alleghany County, North Carolina!!Total!!Estimate
# 8 Alleghany County, North Carolina!!Below poverty level!!Estimate
# 9 Alleghany County, North Carolina!!Percent below poverty level!!Estimate
# 10 Anson County, North Carolina!!Total!!Estimate
# 11 Anson County, North Carolina!!Below poverty level!!Estimate
# 12 Anson County, North Carolina!!Percent below poverty level!!Estimate
# 13 Ashe County, North Carolina!!Total!!Estimate
# 14 Ashe County, North Carolina!!Below poverty level!!Estimate
# 15 Ashe County, North Carolina!!Percent below poverty level!!Estimate
# ...

# %%
for key, value in to_rename.items():
    print (key)
    print(value)
# Out:
#  County, North Carolina!!Total!!Estimate
# _total
#  County, North Carolina!!Below poverty level!!Estimate
# _estimate
#  County, North Carolina!!Percent below poverty level!!Estimate
# _percentage

# %%
for index,col in enumerate(col_names):
    for key, value in to_rename.items():
        col = col.replace(key, value)
    col_names[index] = col

poverty.columns = col_names
poverty.head()
# Out:
#                                    Label (Grouping) Alamance_total  \
# 0  Population for whom poverty status is determined        161,433
# 1                                               AGE            NaN
# 2                                    Under 18 years         36,185
# 3                                     Under 5 years          9,338
# 4                                     5 to 17 years         26,847
#
#   Alamance_estimate Alamance_percentage Alexander_total Alexander_estimate  \
# 0            24,893               15.4%          35,788              4,403
# 1               NaN                 NaN             NaN                NaN
# 2             8,048               22.2%           7,301              1,634
# 3             2,105               22.5%           1,753                389
# 4             5,943               22.1%           5,548              1,245
#
#   Alexander_percentage Alleghany_total Alleghany_estimate  \
# ...

# %%
poverty_income = poverty.iloc[[44,45,46,47,48,49,50,51],:-3] 
poverty_income
# Out:
#                         Label (Grouping) Alamance_total Alamance_estimate  \
# 44           50 percent of poverty level         11,035               (X)
# 45          125 percent of poverty level         34,121               (X)
# 46          150 percent of poverty level         42,094               (X)
# 47          185 percent of poverty level         53,577               (X)
# 48          200 percent of poverty level         59,053               (X)
# 49          300 percent of poverty level         86,311               (X)
# 50          400 percent of poverty level        110,786               (X)
# 51          500 percent of poverty level        126,765               (X)
#
#    Alamance_percentage Alexander_total Alexander_estimate  \
# 44                 (X)           1,854                (X)
# 45                 (X)           6,351                (X)
# 46                 (X)           8,227                (X)
# 47                 (X)          11,298                (X)
# ...

# %%
poverty_income = poverty_income.T.reset_index() 
poverty_income
# Out:
#                    index                                   44  \
# 0       Label (Grouping)          50 percent of poverty level
# 1         Alamance_total                               11,035
# 2      Alamance_estimate                                  (X)
# 3    Alamance_percentage                                  (X)
# 4        Alexander_total                                1,854
# ..                   ...                                  ...
# 296      Yadkin_estimate                                  (X)
# 297    Yadkin_percentage                                  (X)
# 298         Yancey_total                                1,217
# 299      Yancey_estimate                                  (X)
# 300    Yancey_percentage                                  (X)
#
#                                        45  \
# 0            125 percent of poverty level
# 1                                  34,121
# 2                                     (X)
# 3                                     (X)
# ...

# %%
income_cols = ["50 percent of poverty level", "125 percent of poverty level", "150 percent of poverty level", "185 percent of poverty level", "200 percent of poverty level", "300 percent of poverty level", "400 percent of poverty level", "500 percent of poverty level"]
income_cols
# Out:
# ['50 percent of poverty level',
#  '125 percent of poverty level',
#  '150 percent of poverty level',
#  '185 percent of poverty level',
#  '200 percent of poverty level',
#  '300 percent of poverty level',
#  '400 percent of poverty level',
#  '500 percent of poverty level']

# %%
poverty_income.columns = ["counties"] + income_cols 
poverty_income.columns
# Out:
# Index(['counties', '50 percent of poverty level',
#        '125 percent of poverty level', '150 percent of poverty level',
#        '185 percent of poverty level', '200 percent of poverty level',
#        '300 percent of poverty level', '400 percent of poverty level',
#        '500 percent of poverty level'],
#       dtype='object')

# %%
poverty_income = poverty_income.drop(poverty_income.index[0]) 
poverty_income
# Out:
#                 counties 50 percent of poverty level  \
# 1         Alamance_total                      11,035
# 2      Alamance_estimate                         (X)
# 3    Alamance_percentage                         (X)
# 4        Alexander_total                       1,854
# 5     Alexander_estimate                         (X)
# ..                   ...                         ...
# 296      Yadkin_estimate                         (X)
# 297    Yadkin_percentage                         (X)
# 298         Yancey_total                       1,217
# 299      Yancey_estimate                         (X)
# 300    Yancey_percentage                         (X)
#
#     125 percent of poverty level 150 percent of poverty level  \
# 1                         34,121                       42,094
# 2                            (X)                          (X)
# 3                            (X)                          (X)
# 4                          6,351                        8,227
# ...

# %%
poverty_income[poverty_income['counties'].str.contains('_total')]
# Out:
#             counties 50 percent of poverty level 125 percent of poverty level  \
# 1     Alamance_total                      11,035                       34,121
# 4    Alexander_total                       1,854                        6,351
# 7    Alleghany_total                         759                        3,259
# 10       Anson_total                       1,545                        5,544
# 13        Ashe_total                       1,706                        5,939
# ..               ...                         ...                          ...
# 286      Wayne_total                       9,591                       30,344
# 289     Wilkes_total                       4,296                       15,337
# 292     Wilson_total                       6,466                       22,114
# 295     Yadkin_total                       2,546                        7,458
# 298     Yancey_total                       1,217                        3,571
#
# ...

# %%
counties = gpd.read_file('data/NC_Counties/counties.shp')

# %%
poverty_income_tot = poverty_income[poverty_income['counties'].str.contains('_total')].copy()

# %%
poverty_income_tot = poverty_income_tot.replace(',', '', regex=True)

# %%
poverty_income_tot[income_cols] = poverty_income_tot[income_cols].apply(pd.to_numeric, errors='coerce')

# %%
poverty_income_tot.sort_values(by=income_cols)
# Out:
#               counties  50 percent of poverty level  \
# 43        Camden_total                          182
# 265      Tyrrell_total                          240
# 64          Clay_total                          506
# 109        Gates_total                          512
# 112       Graham_total                          600
# ..                 ...                          ...
# 76    Cumberland_total                        26398
# 100      Forsyth_total                        27212
# 121     Guilford_total                        32886
# 274         Wake_total                        41185
# 178  Mecklenburg_total                        51528
#
#      125 percent of poverty level  150 percent of poverty level  \
# 43                           1328                          1784
# 265                           703                           959
# 64                           2047                          2806
# 109                          2399                          2700
# ...

# %%
poverty_income_tot.loc[:,"CO_NAME"] = [n.replace('_total','').upper() for n in poverty_income_tot.counties.to_list()]

# %%
plot_ = counties.merge(poverty_income_tot, how='inner', on='CO_NAME')
plot_.head()
# Out:
#    FID  OBJECTID      PERIMETER     CO_NAME CO_ABBR          ACRES  \
# 0    1       1.0  156472.984375  ROCKINGHAM    ROCK  366053.062500
# 1    2       2.0  166183.500000    GUILFORD    GUIL  420968.937500
# 2    3       3.0  143114.546875    ALAMANCE    ALAM  278127.031250
# 3    4       4.0  116938.171875   ALEXANDER    ALEX  168640.984375
# 4    5       5.0  180894.171875    RANDOLPH    RAND  505667.968750
#
#       Shape_Leng    RO     SHAPE_Le_1    SHAPE_Area  \
# 0  513361.787377  WSRO  194502.424760  1.594526e+10
# 1  545220.367738  WSRO  205797.586927  1.833739e+10
# 2  469534.986553  WSRO  177272.968717  1.211521e+10
# 3  383654.655146   MRO  144599.548259  7.345997e+09
# 4  593483.622166  WSRO  223033.815060  2.202688e+10
#
#                                             geometry          counties  \
# 0  POLYGON ((-8853514.087 4333890.334, -8854417.1...  Rockingham_total
# 1  POLYGON ((-8909472.546 4336065.305, -8906846.4...    Guilford_total
# ...

# %%
poverty_income_totWake = poverty_income_tot[(poverty_income_tot['CO_NAME'] == 'WAKE')]
poverty_income_totWake
# Out:
#        counties  50 percent of poverty level  125 percent of poverty level  \
# 274  Wake_total                        41185                        125264
#
#      150 percent of poverty level  185 percent of poverty level  \
# 274                        155691                        206359
#
#      200 percent of poverty level  300 percent of poverty level  \
# 274                        226025                        366539
#
#      400 percent of poverty level  500 percent of poverty level CO_NAME
# 274                        500454                        626830    WAKE

# %%
plotWake_ = counties.merge(poverty_income_totWake, how='inner', on='CO_NAME')
plotWake_.head()
# Out:
#    FID  OBJECTID      PERIMETER CO_NAME CO_ABBR       ACRES     Shape_Leng  \
# 0   43      43.0  216781.765625    WAKE    WAKE  547995.375  711224.841117
#
#     RO     SHAPE_Le_1    SHAPE_Area  \
# 0  RRO  267577.156743  2.387066e+10
#
#                                             geometry    counties  \
# 0  POLYGON ((-8743775.629 4303587.587, -8739946.4...  Wake_total
#
#    50 percent of poverty level  125 percent of poverty level  \
# 0                        41185                        125264
#
#    150 percent of poverty level  185 percent of poverty level  \
# 0                        155691                        206359
#
#    200 percent of poverty level  300 percent of poverty level  \
# 0                        226025                        366539
#
#    400 percent of poverty level  500 percent of poverty level
# 0                        500454                        626830

# %%
ILcounties = shp[(shp['STATEFP'] == '17')]

ILcounties
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD  \
# 85        17      067  00424235  17067    Hancock    Hancock County   06
# 92        17      025  00424214  17025       Clay       Clay County   06
# 131       17      185  00424293  17185     Wabash     Wabash County   06
# 148       17      113  01784833  17113     McLean     McLean County   06
# 158       17      005  00424204  17005       Bond       Bond County   06
# ...      ...      ...       ...    ...        ...               ...  ...
# 2900      17      111  01784815  17111    McHenry    McHenry County   06
# 2921      17      015  00424209  17015    Carroll    Carroll County   06
# 2988      17      047  00424225  17047    Edwards    Edwards County   06
# 2997      17      071  00424237  17071  Henderson  Henderson County   06
# 3091      17      077  00424240  17077    Jackson    Jackson County   06
#
#      CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# ...

# %%
ILDistricts = shp2[(shp2['STATEFP'] == '17')]

ILDistricts
# Out:
#      STATEFP ELSDLEA SCSDLEA UNSDLEA    GEOID  \
# 5370      17    None   17901    None  1717901
# 5371      17    None   32220    None  1732220
# 5372      17    None   38100    None  1738100
# 5373      17    None   32700    None  1732700
# 5374      17    None   34290    None  1734290
# ...      ...     ...     ...     ...      ...
# 7595      17    None    None   04440  1704440
# 7596      17    None    None   08460  1708460
# 7597      17    None    None   17730  1717730
# 7598      17    None    None   19200  1719200
# 7599      17    None    None   27450  1727450
#
#                                                  NAME LSAD LOGRADE HIGRADE  \
# 5370          Flanagan-Cornell District 74 in Cornell   00      09      12
# 5371         Pontiac Township High School District 90   00      09      12
# 5372        Streator Township High School District 40   00      09      12
# 5373               Princeton High School District 500   00      09      12
# ...

# %%
structuresIL = gpd.read_file('data/Illinois Structures/Shape/Struct_Point.shp')
structuresIL
# Out:
#                                    Permanent_ Source_Fea  \
# 0        a358a11c-0027-45a4-9bad-2daae602b3ee   IL000463
# 1        87cc0180-2103-44dc-bebe-7a7a236b9880   IL000085
# 2        4bf65fba-74d5-44b2-a9e3-d6e963516cb2   IL000742
# 3        b940ee36-d91b-4854-adb4-2a324fab4655   IL000276
# 4        ac20f3ce-8d3b-4690-8063-fc5158a81c3f   IL000864
# ...                                       ...        ...
# 17488  {E0F1BCE3-E0BC-4059-8082-D898FDCB600E}      18653
# 17489  {EA042970-1FA9-4417-9297-A90E0F76893A}      18576
# 17490  {1A3430F4-B0A8-4C04-BE43-2BEAA7D64C4F}      30333
# 17491  {44F5AC91-A3E1-446B-8943-F570D61ECCC1}      30342
# 17492  {72855A2E-5B71-4B1C-9F5C-E067E447505D}       None
#
#                                    Source_Dat  \
# 0        1e49df8d-bb1a-4ab1-a470-ef7e18541c06
# 1        02379378-99e9-409e-89da-a7665ebbf7b6
# 2        a9c44a35-a447-4eb3-88f7-b5c9f0a98b07
# 3        6de4bb77-a0f5-47fa-bcb3-f3af6ca20ce9
# ...

# %%
ILPublic = structuresIL[structuresIL['Name'].str.contains('School')]
ILPublic
# Out:
#                                    Permanent_    Source_Fea  \
# 2426   {0AEA0813-8CF7-426B-AB13-6C0AB936FBA2}  173156003324
# 2427   {88E6736B-BF8E-40E2-A5C2-9AA6C9B337AC}  171203001457
# 2428   {FB73CA02-EEF4-4462-B2C2-3F83D990DF78}  172655005715
# 2429   {0533C39A-D90F-4E13-8489-65AB1B5F62CB}  170000305120
# 2430   {6DC89FCE-7343-4AA7-9FD5-5FA81773DA21}  171446001803
# ...                                       ...           ...
# 17394    34203d3f-bc1a-477c-a42c-f07b4bd19fd9          None
# 17414    1bc74df5-a91e-4662-8260-840acad01b3e          None
# 17415    bcc4bf36-aed3-48bb-b254-41f9211208c1          None
# 17416    1cda01e4-0e71-444a-8e9e-0d30c631c284          None
# 17425    1a48a2f6-33ea-4f53-a3d8-e8cc04a0f9ba          None
#
#                                  Source_Dat                     Source_D_1  \
# 2426   fb03adc6-2c29-4393-9aad-e5a2456ed23d       730 TNMC Update 1/9/2020
# 2427   56d4bf21-bee7-4a0d-a4df-78c1cde911c4       730 TNMC Update 7/2/2018
# ...

# %%
ILPrivate = structuresIL[structuresIL['Name'].str.contains('Academy')]
ILPrivate
# Out:
#                                    Permanent_ Source_Fea  \
# 2438   {3223B0DD-94F1-4D32-A886-BB1E8BD6F1CD}   A0700872
# 2439   {ED0A143D-FD6E-424E-B8B1-0E09446D211C}   A0103180
# 2443   {1CDBAA24-1748-4FDF-9F1B-71AAD689CB55}   A9102367
# 2513   {074E04FE-35EB-4201-B3B3-227FC53E12B4}   A0700866
# 2523   {AB13AB3A-9BE8-470C-A26C-51B79E6E92E7}   A0700831
# ...                                       ...        ...
# 16381    59671373-f187-43df-b1b8-4a22b366ffbe       None
# 16454    436fc48c-e426-4d32-a6ff-dc290412900b       None
# 16777    b7de79a6-5936-4295-9b01-1ebbb0360f36       None
# 16818    447e722f-f684-4a67-86c0-29c0541a3250       None
# 17418    b8739eb9-5512-4bb3-8633-3bce2e1087e0       None
#
#                                  Source_Dat                  Source_D_1  \
# 2438   ba3452e5-d33a-431c-b48d-2f006cf06d29   730 TNMC Update 11/8/2017
# 2439   3a1f15c8-2b07-4b9f-987b-a0cfe094e832    730 TNMC Update 5/2/2022
# ...

# %%
print('IL counties CRS: {0}'.format(ILcounties.crs))
print('IL Districts CRS: {0}'.format(ILDistricts.crs))
print('IL Public School CRS: {0}'.format(ILPublic.crs))
print('IL Private School CRS: {0}'.format(ILPrivate.crs))
# Out:
# IL counties CRS: epsg:4269
# IL Districts CRS: epsg:4269
# IL Public School CRS: epsg:4269
# IL Private School CRS: epsg:4269

# %%
Kendall_District = shp2[(shp2['GEOID'] == '1730270')]
Kendall_District
# Out:
#      STATEFP ELSDLEA SCSDLEA UNSDLEA    GEOID  \
# 7225      17    None    None   30270  1730270
#
#                                            NAME LSAD LOGRADE HIGRADE  MTFCC  \
# 7225  Oswego Community Unit School District 308   00      PK      12  G5420
#
#      SDTYP FUNCSTAT        ALAND     AWATER     INTPTLAT      INTPTLON  \
# 7225  None        E  181727889.0  1451494.0  +41.6538727  -088.3151628
#
#      GEO_YEAR SCHOOLYEAR                                           geometry
# 7225     2021  2020-2021  POLYGON ((-88.22371 41.66948, -88.22371 41.669...

# %%
Kendall_County = ILcounties[(ILcounties['NAME'] == 'Kendall')]
Kendall_County
# Out:
#     STATEFP COUNTYFP  COUNTYNS  GEOID     NAME        NAMELSAD LSAD CLASSFP  \
# 630      17      093  00424248  17093  Kendall  Kendall County   06      H1
#
#      MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT      ALAND   AWATER     INTPTLAT  \
# 630  G4020   176  16980    20994        A  829412776  5136525  +41.5881403
#
#          INTPTLON                                           geometry
# 630  -088.4306257  POLYGON ((-88.36529 41.46049, -88.36667 41.460...

# %%
Kendall_Public = ILPublic[(ILPublic['City'] == 'Oswego')]
Kendall_Public
# Out:
#                                    Permanent_    Source_Fea  \
# 3074   {6158A7BC-C9D2-4F37-AFF1-114B98E6C615}  170023004381
# 3076   {A372E9F5-7E8F-4F2A-A3C2-53AB07F2BC90}  173027003132
# 3768   {3B07037A-F9E0-4E53-BA94-B334A5AF1B48}  173027005365
# 3769   {CE4EED04-33F3-49EA-92E9-AD4C22CBD452}  173027005820
# 3968   {4AA08CCD-8E76-4AF5-8B38-A2FB2DC9B281}  173027005337
# 3969   {3A75D4E8-F7A3-4C3D-9A3D-41826E97A839}  173027005344
# 4145   {A2CA1FE3-7E85-4F54-86E8-3EF4D5629A24}  173027004390
# 4147   {FF785093-6AC9-4AAE-BBBE-2301C8E6A596}  173027002101
# 4148   {F7D2FFC2-D55E-4594-AC12-778DFF0A0A94}  173027003133
# 4150   {4DC0954D-37D9-4BA0-94DF-898DC53BF342}  173027003134
# 17362    01dd36d2-360c-4f12-9316-e465e66b5dd4          None
#
#                                  Source_Dat                  Source_D_1  \
# 3074   925f925a-085c-4ce5-beab-0821d2e15f15  730 TNMC Update 11/15/2017
# 3076   bd8ad572-9443-46c9-906f-30d47bf65cd0    730 TNMC Update 1/4/2021
# ...

# %%
Kendall_Private = ILPrivate[(ILPrivate['City'] == 'Oswego')]
Kendall_Private
# Out:
# Empty GeoDataFrame
# Columns: [Permanent_, Source_Fea, Source_Dat, Source_D_1, Source_Ori, Data_Secur, Distributi, LoadDate, FType, FCode, Name, IsLandmark, PointLocat, AdminType, AddressBui, Address, City, State, Zipcode, GNIS_ID, Foot_ID, Complex_ID, ObjectID, geometry]
# Index: []
#
# [0 rows x 24 columns]

# %%
povertyIL = pd.read_csv('data/Illinois Poverty.csv')
povertyIL.head()
# Out:
#                                    Label (Grouping)  \
# 0  Population for whom poverty status is determined
# 1                                               AGE
# 2                                    Under 18 years
# 3                                     Under 5 years
# 4                                     5 to 17 years
#
#   Baldwin County, Alabama!!Total!!Estimate  \
# 0                                  235,395
# 1                                      NaN
# 2                                   49,621
# 3                                   11,677
# 4                                   37,944
#
#   Baldwin County, Alabama!!Total!!Margin of Error  \
# 0                                          ±2,413
# 1                                             NaN
# 2                                            ±657
# 3                                            ±929
# 4                                            ±789
#
#   Baldwin County, Alabama!!Below poverty level!!Estimate  \
# ...

# %%
ILcol_names = povertyIL.columns.to_list()
ILcol_names
# Out:
# ['Label (Grouping)',
#  'Baldwin County, Alabama!!Total!!Estimate',
#  'Baldwin County, Alabama!!Total!!Margin of Error',
#  'Baldwin County, Alabama!!Below poverty level!!Estimate',
#  'Baldwin County, Alabama!!Below poverty level!!Margin of Error',
#  'Baldwin County, Alabama!!Percent below poverty level!!Estimate',
#  'Baldwin County, Alabama!!Percent below poverty level!!Margin of Error',
#  'Calhoun County, Alabama!!Total!!Estimate',
#  'Calhoun County, Alabama!!Total!!Margin of Error',
#  'Calhoun County, Alabama!!Below poverty level!!Estimate',
#  'Calhoun County, Alabama!!Below poverty level!!Margin of Error',
#  'Calhoun County, Alabama!!Percent below poverty level!!Estimate',
#  'Calhoun County, Alabama!!Percent below poverty level!!Margin of Error',
#  'Cullman County, Alabama!!Total!!Estimate',
#  'Cullman County, Alabama!!Total!!Margin of Error',
#  'Cullman County, Alabama!!Below poverty level!!Estimate',
# ...

# %%
to_renameIL = {' County, Illinois!!Total!!Estimate':'_total',
             ' County, Illinois!!Below poverty level!!Estimate':'_estimate',
             ' County, Illinois!!Percent below poverty level!!Estimate':'_percentage'}
to_renameIL
# Out:
# {' County, Illinois!!Total!!Estimate': '_total',
#  ' County, Illinois!!Below poverty level!!Estimate': '_estimate',
#  ' County, Illinois!!Percent below poverty level!!Estimate': '_percentage'}

# %%
for index,col in enumerate(ILcol_names):
    print(index, col)
# Out:
# 0 Label (Grouping)
# 1 Baldwin County, Alabama!!Total!!Estimate
# 2 Baldwin County, Alabama!!Total!!Margin of Error
# 3 Baldwin County, Alabama!!Below poverty level!!Estimate
# 4 Baldwin County, Alabama!!Below poverty level!!Margin of Error
# 5 Baldwin County, Alabama!!Percent below poverty level!!Estimate
# 6 Baldwin County, Alabama!!Percent below poverty level!!Margin of Error
# 7 Calhoun County, Alabama!!Total!!Estimate
# 8 Calhoun County, Alabama!!Total!!Margin of Error
# 9 Calhoun County, Alabama!!Below poverty level!!Estimate
# 10 Calhoun County, Alabama!!Below poverty level!!Margin of Error
# 11 Calhoun County, Alabama!!Percent below poverty level!!Estimate
# 12 Calhoun County, Alabama!!Percent below poverty level!!Margin of Error
# 13 Cullman County, Alabama!!Total!!Estimate
# 14 Cullman County, Alabama!!Total!!Margin of Error
# 15 Cullman County, Alabama!!Below poverty level!!Estimate
# 16 Cullman County, Alabama!!Below poverty level!!Margin of Error
# ...

# %%
for key, value in to_renameIL.items():
    print (key)
    print(value)
# Out:
#  County, Illinois!!Total!!Estimate
# _total
#  County, Illinois!!Below poverty level!!Estimate
# _estimate
#  County, Illinois!!Percent below poverty level!!Estimate
# _percentage

# %%
for index,col in enumerate(ILcol_names):
    for key, value in to_renameIL.items():
        col = col.replace(key, value)
    ILcol_names[index] = col
povertyIL.columns = ILcol_names
povertyIL.head()
# Out:
#                                    Label (Grouping)  \
# 0  Population for whom poverty status is determined
# 1                                               AGE
# 2                                    Under 18 years
# 3                                     Under 5 years
# 4                                     5 to 17 years
#
#   Baldwin County, Alabama!!Total!!Estimate  \
# 0                                  235,395
# 1                                      NaN
# 2                                   49,621
# 3                                   11,677
# 4                                   37,944
#
#   Baldwin County, Alabama!!Total!!Margin of Error  \
# 0                                          ±2,413
# 1                                             NaN
# 2                                            ±657
# 3                                            ±929
# 4                                            ±789
#
#   Baldwin County, Alabama!!Below poverty level!!Estimate  \
# ...

# %%
poverty_incomeIL = povertyIL.iloc[[44,45,46,47,48,49,50,51],:-3]  
poverty_incomeIL
# Out:
#                         Label (Grouping)  \
# 44           50 percent of poverty level
# 45          125 percent of poverty level
# 46          150 percent of poverty level
# 47          185 percent of poverty level
# 48          200 percent of poverty level
# 49          300 percent of poverty level
# 50          400 percent of poverty level
# 51          500 percent of poverty level
#
#    Baldwin County, Alabama!!Total!!Estimate  \
# 44                                   14,846
# 45                                   34,204
# 46                                   44,425
# 47                                   55,796
# 48                                   61,445
# 49                                   99,250
# 50                                  135,882
# 51                                  166,339
#
#    Baldwin County, Alabama!!Total!!Margin of Error  \
# 44                                          ±3,964
# 45                                          ±5,526
# ...

# %%
poverty_incomeIL = poverty_incomeIL.T.reset_index() 
poverty_incomeIL
# Out:
#                                                   index  \
# 0                                      Label (Grouping)
# 1              Baldwin County, Alabama!!Total!!Estimate
# 2       Baldwin County, Alabama!!Total!!Margin of Error
# 3     Baldwin County, Alabama!!Below poverty level!!...
# 4     Baldwin County, Alabama!!Below poverty level!!...
# ...                                                 ...
# 5045  Trujillo Alto Municipio, Puerto Rico!!Percent ...
# 5046  Trujillo Alto Municipio, Puerto Rico!!Percent ...
# 5047                          Illinois!!Total!!Estimate
# 5048                   Illinois!!Total!!Margin of Error
# 5049            Illinois!!Below poverty level!!Estimate
#
#                                        44  \
# 0             50 percent of poverty level
# 1                                  14,846
# 2                                  ±3,964
# 3                                     (X)
# 4                                     (X)
# ...

# %%
ILincome_cols = ["50 percent of poverty level", "125 percent of poverty level", "150 percent of poverty level", "185 percent of poverty level", "200 percent of poverty level", "300 percent of poverty level", "400 percent of poverty level", "500 percent of poverty level"]
ILincome_cols
# Out:
# ['50 percent of poverty level',
#  '125 percent of poverty level',
#  '150 percent of poverty level',
#  '185 percent of poverty level',
#  '200 percent of poverty level',
#  '300 percent of poverty level',
#  '400 percent of poverty level',
#  '500 percent of poverty level']

# %%
poverty_incomeIL.columns = ["counties"] + ILincome_cols 
poverty_incomeIL.columns
# Out:
# Index(['counties', '50 percent of poverty level',
#        '125 percent of poverty level', '150 percent of poverty level',
#        '185 percent of poverty level', '200 percent of poverty level',
#        '300 percent of poverty level', '400 percent of poverty level',
#        '500 percent of poverty level'],
#       dtype='object')

# %%
poverty_incomeIL = poverty_incomeIL.drop(poverty_incomeIL.index[0]) 
poverty_incomeIL
# Out:
#                                                counties  \
# 1              Baldwin County, Alabama!!Total!!Estimate
# 2       Baldwin County, Alabama!!Total!!Margin of Error
# 3     Baldwin County, Alabama!!Below poverty level!!...
# 4     Baldwin County, Alabama!!Below poverty level!!...
# 5     Baldwin County, Alabama!!Percent below poverty...
# ...                                                 ...
# 5045  Trujillo Alto Municipio, Puerto Rico!!Percent ...
# 5046  Trujillo Alto Municipio, Puerto Rico!!Percent ...
# 5047                          Illinois!!Total!!Estimate
# 5048                   Illinois!!Total!!Margin of Error
# 5049            Illinois!!Below poverty level!!Estimate
#
#      50 percent of poverty level 125 percent of poverty level  \
# 1                         14,846                       34,204
# 2                         ±3,964                       ±5,526
# 3                            (X)                          (X)
# ...

# %%
poverty_incomeIL[poverty_incomeIL['counties'].str.contains('_total')]
# Out:
#                counties 50 percent of poverty level  \
# 1201    Champaign_total                      19,015
# 1207         Cook_total                     352,119
# 1213       DeKalb_total                       8,717
# 1219       DuPage_total                      32,150
# 1225         Kane_total                      17,576
# 1231     Kankakee_total                       6,158
# 1237      Kendall_total                       5,187
# 1243         Lake_total                      25,115
# 1249      LaSalle_total                       7,078
# 1255      McHenry_total                       8,985
# 1261       McLean_total                      15,031
# 1267        Macon_total                       8,594
# 1273      Madison_total                      13,644
# 1279       Peoria_total                      13,136
# 1285  Rock Island_total                      11,205
# 1291    St. Clair_total                      16,544
# 1297     Sangamon_total                      15,993
# ...

# %%
countiesUSGS = gpd.read_file('data/Illinois Counties/Shape/GU_CountyOrEquivalent.shp')
countiesUSGS
# Out:
#                                permanent_ source_fea  \
# 0    f80293a6-85fd-4f39-8ebb-7fb55c485930      17169
# 1    8b5b5533-8c14-48d0-8841-cdda0d4976f3      17195
# 2    a2e6c42e-3f3b-48d3-a0b1-a21dfb7f33d8      17049
# 3    2084c734-7aad-4909-adcd-9335e2d07736      17005
# 4    a76012cf-1f7a-43bb-94ea-92e317ad2019      17125
# ..                                    ...        ...
# 97   3dd6dac7-a1f2-4a7d-9313-c042558a6b9b      17001
# 98   cd602bb4-6907-4639-967d-ca1c0e99d504      17161
# 99   871b2d51-8c63-4153-adbd-390eab40b7d1      17011
# 100  b6c718ac-dace-4e1d-a904-cf391f8d9d6c      17137
# 101  93f252c4-3e26-4076-95ca-ce99f5acba9f      17057
#
#                                source_dat  \
# 0    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 1    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 2    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 3    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 4    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# ..                                    ...
# ...

# %%
countiesUSGS ['county_nam'] = countiesUSGS['county_nam'].str.upper()
countiesUSGS
# Out:
#                                permanent_ source_fea  \
# 0    f80293a6-85fd-4f39-8ebb-7fb55c485930      17169
# 1    8b5b5533-8c14-48d0-8841-cdda0d4976f3      17195
# 2    a2e6c42e-3f3b-48d3-a0b1-a21dfb7f33d8      17049
# 3    2084c734-7aad-4909-adcd-9335e2d07736      17005
# 4    a76012cf-1f7a-43bb-94ea-92e317ad2019      17125
# ..                                    ...        ...
# 97   3dd6dac7-a1f2-4a7d-9313-c042558a6b9b      17001
# 98   cd602bb4-6907-4639-967d-ca1c0e99d504      17161
# 99   871b2d51-8c63-4153-adbd-390eab40b7d1      17011
# 100  b6c718ac-dace-4e1d-a904-cf391f8d9d6c      17137
# 101  93f252c4-3e26-4076-95ca-ce99f5acba9f      17057
#
#                                source_dat  \
# 0    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 1    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 2    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 3    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# 4    862682ca-fbab-4d47-a9ef-6cd9a0d16f14
# ..                                    ...
# ...

# %%
poverty_income_totIL = poverty_incomeIL[poverty_incomeIL['counties'].str.contains('_total')].copy()

# %%
poverty_income_totIL = poverty_income_totIL.replace(',', '', regex=True)

# %%
poverty_income_totIL[ILincome_cols] = poverty_income_totIL[ILincome_cols].apply(pd.to_numeric, errors='coerce')

# %%
poverty_income_totIL.sort_values(by=ILincome_cols)
# Out:
#                counties  50 percent of poverty level  \
# 1321   Williamson_total                         4416
# 1309    Vermilion_total                         5082
# 1237      Kendall_total                         5187
# 1303     Tazewell_total                         5973
# 1231     Kankakee_total                         6158
# 1249      LaSalle_total                         7078
# 1267        Macon_total                         8594
# 1213       DeKalb_total                         8717
# 1255      McHenry_total                         8985
# 1285  Rock Island_total                        11205
# 1279       Peoria_total                        13136
# 1273      Madison_total                        13644
# 1261       McLean_total                        15031
# 1297     Sangamon_total                        15993
# 1291    St. Clair_total                        16544
# 1225         Kane_total                        17576
# 1201    Champaign_total                        19015
# ...

# %%
poverty_income_totIL.loc[:,"county_nam"] = [n.replace('_total','').upper() for n in poverty_income_totIL.counties.to_list()]
poverty_income_totIL
# Out:
#                counties  50 percent of poverty level  \
# 1201    Champaign_total                        19015
# 1207         Cook_total                       352119
# 1213       DeKalb_total                         8717
# 1219       DuPage_total                        32150
# 1225         Kane_total                        17576
# 1231     Kankakee_total                         6158
# 1237      Kendall_total                         5187
# 1243         Lake_total                        25115
# 1249      LaSalle_total                         7078
# 1255      McHenry_total                         8985
# 1261       McLean_total                        15031
# 1267        Macon_total                         8594
# 1273      Madison_total                        13644
# 1279       Peoria_total                        13136
# 1285  Rock Island_total                        11205
# 1291    St. Clair_total                        16544
# 1297     Sangamon_total                        15993
# ...

# %%
plotIL_ = countiesUSGS.merge(poverty_income_totIL, how='inner', on='county_nam')
plotIL_
# Out:
#                               permanent_ source_fea  \
# 0   0953e502-913b-4b87-ac08-5ec7f8f5ea36      17179
# 1   54b5401b-90b0-4626-b1c7-14802d92c542      17037
# 2   4b46f23c-95fa-42b1-88a1-d1979c99eb92      17043
# 3   3662b7bd-1300-40ac-9ab5-4e5a22926502      17091
# 4   cca45979-e51d-4b38-9cc4-4d4b77131f23      17089
# 5   5bde2f61-0ef9-478d-ae7b-652c5c5357ed      17111
# 6   85b3c9aa-762c-4e47-ac3f-7b16b6d80426      17163
# 7   87eb709b-649f-4aca-b41f-016b3711f529      17113
# 8   264d914e-ac2c-4742-a821-bfbb29ef7f4c      17201
# 9   5e29743c-222b-4026-923f-257743b630b3      17019
# 10  296e0c04-68cc-45a4-94ac-4042f0e55ec1      17097
# 11  6aa9d44c-bca6-4cd7-8304-b9e10d10cd61      17197
# 12  109655c7-38fb-4353-8cc4-ecd07f98f3bc      17167
# 13  b4810713-ebf8-48b3-9d1a-df272c13a1ac      17119
# 14  8ff5829b-0712-422c-a23d-17cbe29c5cdc      17143
# 15  5f9e70ad-de6e-4eee-a88b-f0f8471203b9      17115
# 16  620077c5-1a69-43cc-a9d9-0b9976eb7543      17093
# ...

# %%
poverty_income_totKendall = poverty_income_totIL[(poverty_income_totIL['county_nam'] == 'KENDALL')]
poverty_income_totKendall
# Out:
#            counties  50 percent of poverty level  \
# 1237  Kendall_total                         5187
#
#       125 percent of poverty level  150 percent of poverty level  \
# 1237                         10396                         11590
#
#       185 percent of poverty level  200 percent of poverty level  \
# 1237                         20619                         21050
#
#       300 percent of poverty level  400 percent of poverty level  \
# 1237                         46861                         68293
#
#       500 percent of poverty level county_nam
# 1237                         87373    KENDALL

# %%
plotKendall_ = countiesUSGS.merge(poverty_income_totKendall, how='inner', on='county_nam')
plotKendall_.head()
# Out:
#                              permanent_ source_fea  \
# 0  620077c5-1a69-43cc-a9d9-0b9976eb7543      17093
#
#                              source_dat  \
# 0  862682ca-fbab-4d47-a9ef-6cd9a0d16f14
#
#                                           source_d_1          source_ori  \
# 0  2020 TIGER/Line Shapefile, Current County and ...  U.S. Census Bureau
#
#      loaddate  fcode state_fips state_name county_fip  ...  \
# 0  2021-06-02  61200         17   Illinois        093  ...
#
#                                             geometry       counties  \
# 0  POLYGON ((-88.48967 41.72112, -88.48919 41.721...  Kendall_total
#
#    50 percent of poverty level  125 percent of poverty level  \
# 0                         5187                         10396
#
#   150 percent of poverty level 185 percent of poverty level  \
# 0                        11590                        20619
#
#    200 percent of poverty level  300 percent of poverty level  \
# ...

# %%
nc_public_wgs84 = NCPublic42.to_crs(epsg=4326)
nc_private_wgs84 = NCPrivate42.to_crs(epsg=4326)
nc_districts_wgs84 = NCDistricts.to_crs(epsg=4326)
nc_counties_wgs84 = NCcounties.to_crs(epsg=4326)
IL_counties_wgs84 = ILcounties.to_crs(epsg=4326)
IL_districts_wgs84 = ILDistricts.to_crs(epsg=4326)
IL_public_wgs84 = ILPublic.to_crs(epsg=4326)
IL_private_wgs84 = ILPrivate.to_crs(epsg=4326)
Wake_public_wgs84 = Wake_Public.to_crs(epsg=4326)
Wake_private_wgs84 = Wake_Private.to_crs(epsg=4326)
Wake_counties_wgs84 = Wake_County.to_crs(epsg=4326)
Wake_districts_wgs84 = Wake_District.to_crs(epsg=4326)
Kendall_public_wgs84 = Kendall_Public.to_crs(epsg=4326)
Kendall_private_wgs84 = Kendall_Private.to_crs(epsg=4326)
Kendall_counties_wgs84 = Kendall_County.to_crs(epsg=4326)
Kendall_districts_wgs84 = Kendall_District.to_crs(epsg=4326)

# %%
nc_public_wgs84['geoid'] = nc_public_wgs84.index.astype(str)
nc_private_wgs84['geoid'] = nc_private_wgs84.index.astype(str)
nc_districts_wgs84['geoid'] = nc_districts_wgs84.index.astype(str)
nc_counties_wgs84['geoid'] = nc_counties_wgs84.index.astype(str)
IL_counties_wgs84['geoid'] = IL_counties_wgs84.index.astype(str)
IL_districts_wgs84['geoid'] = IL_districts_wgs84.index.astype(str)
IL_public_wgs84['geoid'] = IL_public_wgs84.index.astype(str)
IL_private_wgs84['geoid'] = IL_private_wgs84.index.astype(str)
Wake_public_wgs84['geoid'] = Wake_public_wgs84.index.astype(str)
Wake_private_wgs84['geoid'] = Wake_private_wgs84.index.astype(str)
Wake_counties_wgs84['geoid'] = Wake_counties_wgs84.index.astype(str)
Wake_districts_wgs84['geoid'] = Wake_districts_wgs84.index.astype(str)
Kendall_public_wgs84['geoid'] = Kendall_public_wgs84.index.astype(str)
Kendall_private_wgs84['geoid'] = Kendall_private_wgs84.index.astype(str)
Kendall_counties_wgs84['geoid'] = Kendall_counties_wgs84.index.astype(str)
Kendall_districts_wgs84['geoid'] = Kendall_districts_wgs84.index.astype(str)

# %%
c = folium.Map(location=[35.782169, -80.793457], zoom_start=8, control_scale=True)
c
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[35.7796, -78.6382], zoom_start=8, control_scale=True)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
n = folium.Map(location=[40.113937, -89.15877], zoom_start=8, control_scale=True)
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
a = folium.Map(location=[41.6828074, -88.3514596], zoom_start=8, control_scale=True)
a
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
chapter_df = pd.read_csv('./csv/Chapters.csv')
chapter_df
# Out:
#                          Chapter  Media Link  Media Cedit  Media Credit Link  \
# 0     Overview of North Carolina         NaN          NaN                NaN
# 1  North Carolina Poverty Spread         NaN          NaN                NaN
# 2        Overview of Wake County         NaN          NaN                NaN
# 3     Wake County Poverty Spread         NaN          NaN                NaN
# 4           Overview of Illinois         NaN          NaN                NaN
# 5         Ilinois Poverty Spread         NaN          NaN                NaN
# 6     Overview of Kendall County         NaN          NaN                NaN
# 7  Kendall County Poverty Spread         NaN          NaN                NaN
#
#    Description  Zoom  Marker  Marker Color   Location  Latitiude  Longitude  \
# 0          NaN   NaN     NaN           NaN        NaN        NaN        NaN
# 1          NaN   NaN     NaN           NaN        NaN        NaN        NaN
# ...

# %%
chapter_df.columns
# Out:
# Index(['Chapter', 'Media Link', 'Media Cedit', 'Media Credit Link',
#        'Description', 'Zoom', 'Marker', 'Marker Color', ' Location',
#        'Latitiude', 'Longitude', 'Overlay', 'Overlay Transparency',
#        'GeoJSON Overlay', 'GeoJSON Feature Properties'],
#       dtype='object')

# %%
chapter_df.loc[[0], ['Media Link']] = 'media/North Carolina Overlay.jpg'

chapter_df.loc[[0], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[0], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[0], ['Description']] = 'The North Carolina map displays several private schools near the cities of Raleigh, Wilmington, and Asheville. \
    There is an outlier, however, in the North Eastern part of North Carolina. This could be from high agriculture production making few people that live in the area causing the government to not fund for public schools, which makes funding for private schools necessary.'
    
chapter_df.loc[[0], ['Zoom']] = 6

chapter_df.loc[[0], ['Marker']] = 'Hidden'

chapter_df.loc[[0], ['Marker Color']] = ''

chapter_df.loc[[0], ['Location']] = 'North Carolina'
chapter_df.loc[[0], ['Latitude']] = 35.782169
chapter_df.loc[[0], ['Longitude']] = -80.793457

chapter_df.loc[[0], ['Overlay']] = 'None'

chapter_df.loc[[0], ['Overlay Transparency']] = 0.9

# %%
chapter_df.loc[[1], ['Media Link']] = 'media/North Carolina Poverty Spread.jpg'

chapter_df.loc[[1], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[1], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[1], ['Description']] = 'From the poverty spread, North Carolina represents a strong correlation between the location of private schools and higher income communities. \
    The amount of people above the various poverty levels are represented near the cities and the cities from the previous map shown exemplify private schools.'
    
chapter_df.loc[[1], ['Zoom']] = 6

chapter_df.loc[[1], ['Marker']] = 'Hidden'

chapter_df.loc[[1], ['Marker Color']] = ''

chapter_df.loc[[1], ['Location']] = 'North Carolina'
chapter_df.loc[[1], ['Latitude']] = 35.782169 
chapter_df.loc[[1], ['Longitude']] = -80.793457

chapter_df.loc[[1], ['Overlay']] = 'None'

chapter_df.loc[[1], ['Overlay Transparency']] = 0.9

# %%
chapter_df.loc[[2], ['Media Link']] = 'media/Wake County Overlay.jpg'

chapter_df.loc[[2], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[2], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[2], ['Description']] = 'Wake County has several private schools listed in it. \
    It has almost an equal amount of private schools as there public schools in the area. \
    It needs all of these schools because it holds the city of Raleigh and several hundreds of thousands of people live there. '
    
chapter_df.loc[[2], ['Zoom']] = 15.75

chapter_df.loc[[2], ['Marker']] = 'Hidden'

chapter_df.loc[[2], ['Marker Color']] = ''

chapter_df.loc[[2], ['Location']] = 'Wake County'
chapter_df.loc[[2], ['Latitude']] = 35.8032
chapter_df.loc[[2], ['Longitude']] = -78.5661

chapter_df.loc[[2], ['Overlay']] = 'None'

chapter_df.loc[[2], ['Overlay Transparency']] = 0.9

# %%
chapter_df.loc[[3], ['Media Link']] = 'media/Wake County Poverty Spread.jpg'

chapter_df.loc[[3], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[3], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[3], ['Description']] = 'Wake County is an econopmically feasible area to live in. \
    It holds hundred of thousnads of people in it and displays thousands of people well over the poverty line. \
    It speaks to the correlation of private schools being near the city due to Wake COunty holding Raleigh and the high amount of prosperous people. '
    
chapter_df.loc[[3], ['Zoom']] = 15.75

chapter_df.loc[[3], ['Marker']] = 'Hidden'

chapter_df.loc[[3], ['Marker Color']] = ''

chapter_df.loc[[3], ['Location']] = 'Wake County'
chapter_df.loc[[3], ['Latitude']] = 35.8032
chapter_df.loc[[3], ['Longitude']] = -78.5661

chapter_df.loc[[3], ['Overlay']] = 'None'

chapter_df.loc[[3], ['Overlay Transparency']] = 0.9

# %%
chapter_df.loc[[4], ['Media Link']] = 'media/Illinois Overlay.jpg'

chapter_df.loc[[4], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[4], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[4], ['Description']] = 'Illinois has very few private schools. \
    Most of the private schools listed in Illinois take place in Cook County where Chicago is, Rockford, East St. Louis and Springfield. \
    There is an outlier in the souther tip of Illinois, which can result from needing private systems due to the low population from agricultural land being there and the state government not wanting to fund these areas'
    
chapter_df.loc[[4], ['Zoom']] = 6

chapter_df.loc[[4], ['Marker']] = 'Hidden'

chapter_df.loc[[4], ['Marker Color']] = ''

chapter_df.loc[[4], ['Location']] = 'Illinois'
chapter_df.loc[[4], ['Latitude']] = 40.000000
chapter_df.loc[[4], ['Longitude']] = -89.000000

chapter_df.loc[[4], ['Overlay']] = 'None'

chapter_df.loc[[4], ['Overlay Transparency']] = 0.9

# %%
chapter_df.loc[[5], ['Media Link']] = 'media/Illinois Poverty Spread.jpg'

chapter_df.loc[[5], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[5], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[5], ['Description']] = 'From the poverty spread, Illinois represents a strong correlation between the location of private schools and higher income communities. \
    Cook County and even Rockford are the two highest earning communities and cna be shown in the poverty spread maps. \
    These two areas have the most amount of private schoola in the state of Illinois and makes sense for the income involved there.'
    
chapter_df.loc[[5], ['Zoom']] = 6

chapter_df.loc[[5], ['Marker']] = 'Hidden'

chapter_df.loc[[5], ['Marker Color']] = ''

chapter_df.loc[[5], ['Location']] = 'Illinois'
chapter_df.loc[[5], ['Latitude']] = 40.000000
chapter_df.loc[[5], ['Longitude']] = -89.000000

chapter_df.loc[[5], ['Overlay']] = 'None'

chapter_df.loc[[5], ['Overlay Transparency']] = 0.9

# %%
chapter_df.loc[[6], ['Media Link']] = 'media/Kendall County Overlay.jpg'

chapter_df.loc[[6], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[6], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[6], ['Description']] = 'Kendall County, more specifically, Oswego only shows public schools in the area. \
    This could be from doing a selct by attribute to take out the religous private schools in the area to only look at private institutions that could appeal to the upper class. \
    This conclusion can be supported because I grew up in the area and know that all the private schools in the area are religous catholic schools.'
    
chapter_df.loc[[6], ['Zoom']] = 15.75

chapter_df.loc[[6], ['Marker']] = 'Hidden'

chapter_df.loc[[6], ['Marker Color']] = ''

chapter_df.loc[[6], ['Location']] = 'Kendall County'
chapter_df.loc[[6], ['Latitude']] = 41.5507
chapter_df.loc[[6], ['Longitude']] = -88.4404

chapter_df.loc[[6], ['Overlay']] = 'None'

chapter_df.loc[[6], ['Overlay Transparency']] = 0.9

# %%
chapter_df.loc[[7], ['Media Link']] = 'media/Kendall County Poverty Spread.jpg'

chapter_df.loc[[7], ['Media Credit']] = 'Source: USGS, Tiger Line, IES - NCES, NC One Map, US Census Bureau'

chapter_df.loc[[7], ['Media Credit Link']] = 'N/A'

chapter_df.loc[[7], ['Description']] = 'From the Kendall County povery spread maps, Kendall County portrays a high economic class community. \
    This makes it interesting because no public schools were shown in the Oswegoland area. \
    However, as discussed earlier, most of those schools could be religous and taken away from the school crtieria I am looking for. \
    Also the school system could be in great shape, which makes it to where no private institutions are needed to support all the social classes that go to these schools'
    
chapter_df.loc[[7], ['Zoom']] = 15.75

chapter_df.loc[[7], ['Marker']] = 'Hidden'

chapter_df.loc[[7], ['Marker Color']] = ''

chapter_df.loc[[7], ['Location']] = 'Kendall County'
chapter_df.loc[[7], ['Latitude']] = 41.5507 
chapter_df.loc[[7], ['Longitude']] = -88.4404

chapter_df.loc[[7], ['Overlay']] = 'None'

chapter_df.loc[[7], ['Overlay Transparency']] = 0.9

# %%
chapter_df
# Out:
#                          Chapter                               Media Link  \
# 0     Overview of North Carolina         media/North Carolina Overlay.jpg
# 1  North Carolina Poverty Spread  media/North Carolina Poverty Spread.jpg
# 2        Overview of Wake County            media/Wake County Overlay.jpg
# 3     Wake County Poverty Spread     media/Wake County Poverty Spread.jpg
# 4           Overview of Illinois               media/Illinois Overlay.jpg
# 5         Ilinois Poverty Spread        media/Illinois Poverty Spread.jpg
# 6     Overview of Kendall County         media/Kendall County Overlay.jpg
# 7  Kendall County Poverty Spread  media/Kendall County Poverty Spread.jpg
#
#    Media Cedit Media Credit Link  \
# 0          NaN               N/A
# 1          NaN               N/A
# 2          NaN               N/A
# 3          NaN               N/A
# 4          NaN               N/A
# 5          NaN               N/A
# 6          NaN               N/A
# ...

# %%
chapter_df.to_csv('./csv/Chapters.csv')

# %%
chapter_df.loc[0, "GeoJSON Overlay"] = "geojson/North Carolina Counties.geojson"

chapter_df.loc[0, "GeoJSON Feature Properties"] = "fillColor:red;color:black"

# %%
chapter_df.loc[1, "GeoJSON Overlay"] = "geojson/North Carolina Counties.geojson"

chapter_df.loc[1, "GeoJSON Feature Properties"] = "fillColor:red;color:black"

# %%
chapter_df.loc[2, "GeoJSON Overlay"] = "geojson/Wake County.geojson"

chapter_df.loc[2, "GeoJSON Feature Properties"] = "fillColor:orange;color:black"

# %%
chapter_df.loc[2, "GeoJSON Overlay"] = "geojson/Wake County.geojson"

chapter_df.loc[2, "GeoJSON Feature Properties"] = "fillColor:orange;color:black"

# %%
chapter_df.loc[4, "GeoJSON Overlay"] = "geojson/Illinois Counties.geojson"

chapter_df.loc[4, "GeoJSON Feature Properties"] = "fillColor:blue;color:yellow"

# %%
chapter_df.loc[5, "GeoJSON Overlay"] = "geojson/Illinois Counties.geojson"

chapter_df.loc[5, "GeoJSON Feature Properties"] = "fillColor:blue;color:yellow"

# %%
chapter_df.loc[6, "GeoJSON Overlay"] = "geojson/Kendall County.geojson"

chapter_df.loc[6, "GeoJSON Feature Properties"] = "fillColor:grey;color:yellow"

# %%
chapter_df.loc[7, "GeoJSON Overlay"] = "geojson/Kendall County.geojson"

chapter_df.loc[7, "GeoJSON Feature Properties"] = "fillColor:grey;color:yellow"

# %%
chapter_df.to_csv('./csv/Chapters.csv')
